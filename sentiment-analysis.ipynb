# %%
import pandas as pd

books = pd.read_csv('books_with_categories.csv')

# %%
from transformers import pipeline

classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base",
                      top_k=None,
                      device=0)
classifier('I love this!')
# Out:
# Device set to use cuda:0
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528684265911579},
#   {'label': 'neutral', 'score': 0.0057645998895168304},
#   {'label': 'anger', 'score': 0.004419790115207434},
#   {'label': 'sadness', 'score': 0.002092393347993493},
#   {'label': 'disgust', 'score': 0.0016119939973577857},
#   {'label': 'fear', 'score': 0.0004138524236623198}]]

# %%
classifier(books['description'][0].split('.'))
# Out:
# [[{'label': 'surprise', 'score': 0.7296026349067688},
#   {'label': 'neutral', 'score': 0.14038580656051636},
#   {'label': 'fear', 'score': 0.06816219538450241},
#   {'label': 'joy', 'score': 0.04794240742921829},
#   {'label': 'anger', 'score': 0.009156355634331703},
#   {'label': 'disgust', 'score': 0.0026284761261194944},
#   {'label': 'sadness', 'score': 0.0021221614442765713}],
#  [{'label': 'neutral', 'score': 0.449370801448822},
#   {'label': 'disgust', 'score': 0.27359142899513245},
#   {'label': 'joy', 'score': 0.10908301174640656},
#   {'label': 'sadness', 'score': 0.09362722933292389},
#   {'label': 'anger', 'score': 0.04047824814915657},
#   {'label': 'surprise', 'score': 0.026970194652676582},
#   {'label': 'fear', 'score': 0.006879045628011227}],
#  [{'label': 'neutral', 'score': 0.6462159156799316},
#   {'label': 'sadness', 'score': 0.24273337423801422},
#   {'label': 'disgust', 'score': 0.04342271015048027},
#   {'label': 'surprise', 'score': 0.02830049768090248},
#   {'label': 'joy', 'score': 0.014211454428732395},
#   {'label': 'fear', 'score': 0.01408411655575037},
#   {'label': 'anger', 'score': 0.011031890287995338}],
#  [{'label': 'fear', 'score': 0.9281682968139648},
#   {'label': 'anger', 'score': 0.03219086676836014},
#   {'label': 'neutral', 'score': 0.012808678671717644},
#   {'label': 'sadness', 'score': 0.00875683780759573},
#   {'label': 'surprise', 'score': 0.00859790574759245},
#   {'label': 'disgust', 'score': 0.008431803435087204},
#   {'label': 'joy', 'score': 0.0010455818846821785}],
#  [{'label': 'sadness', 'score': 0.9671574234962463},
#   {'label': 'neutral', 'score': 0.015104176476597786},
#   {'label': 'disgust', 'score': 0.0064806039445102215},
#   {'label': 'fear', 'score': 0.005393999628722668},
#   {'label': 'surprise', 'score': 0.0022869438398629427},
#   {'label': 'anger', 'score': 0.00184289098251611},
#   {'label': 'joy', 'score': 0.0017338828183710575}],
#  [{'label': 'joy', 'score': 0.9327976107597351},
#   {'label': 'disgust', 'score': 0.03771744668483734},
#   {'label': 'neutral', 'score': 0.015891894698143005},
#   {'label': 'sadness', 'score': 0.006444521248340607},
#   {'label': 'anger', 'score': 0.0050249965861439705},
#   {'label': 'surprise', 'score': 0.0015812080819159746},
#   {'label': 'fear', 'score': 0.0005423082620836794}],
#  [{'label': 'joy', 'score': 0.6528711318969727},
#   {'label': 'neutral', 'score': 0.2542743980884552},
#   {'label': 'surprise', 'score': 0.06808298826217651},
#   {'label': 'sadness', 'score': 0.009908966720104218},
#   {'label': 'disgust', 'score': 0.0065122079104185104},
#   {'label': 'anger', 'score': 0.004821309354156256},
#   {'label': 'fear', 'score': 0.0035290122032165527}],
#  [{'label': 'neutral', 'score': 0.5494768619537354},
#   {'label': 'sadness', 'score': 0.11169017106294632},
#   {'label': 'disgust', 'score': 0.10400664806365967},
#   {'label': 'surprise', 'score': 0.07876549661159515},
#   {'label': 'anger', 'score': 0.06413362175226212},
#   {'label': 'fear', 'score': 0.05136280506849289},
#   {'label': 'joy', 'score': 0.0405643992125988}]]

# %%
sentences = books['description'][0].split('.')
predictions = classifier(sentences)
sorted(predictions[0], key=lambda x: x['label'])
# Out:
# [{'label': 'anger', 'score': 0.009156355634331703},
#  {'label': 'disgust', 'score': 0.0026284761261194944},
#  {'label': 'fear', 'score': 0.06816219538450241},
#  {'label': 'joy', 'score': 0.04794240742921829},
#  {'label': 'neutral', 'score': 0.14038580656051636},
#  {'label': 'sadness', 'score': 0.0021221614442765713},
#  {'label': 'surprise', 'score': 0.7296026349067688}]

# %%
import numpy as np

emotion_labels = ['anger', 'disgust', 'fear', 'joy', 'neutral', 'sadness', 'surprise']
isbn = []
emotion_scores = { label: [] for label in emotion_labels }

def calculate_max_emotion_score(predictions):
    per_emotion_scores = { label: [] for label in emotion_labels }
    for prediction in predictions:
        sorted_prediction = sorted(prediction, key=lambda x: x['label'])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_prediction[index]['score'])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
from tqdm import tqdm

for i in tqdm(range(len(books))):
    isbn.append(books['isbn13'][i])
    sentences = books['description'][i].split('.')
    predictions = classifier(sentences)
    max_score = calculate_max_emotion_score(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_score[label])
# Out:
# 100%|██████████| 5197/5197 [03:58<00:00, 21.81it/s]

# %%
emotion_df = pd.DataFrame(emotion_scores)
emotion_df['isbn13'] = isbn

# %%
emotion_df
# Out:
#          anger   disgust      fear       joy   neutral   sadness  surprise  \
# 0     0.064134  0.273591  0.928168  0.932798  0.646216  0.967157  0.729603
# 1     0.612619  0.348285  0.942528  0.704421  0.887939  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# 3     0.351483  0.150722  0.360707  0.251881  0.732686  0.111690  0.078765
# 4     0.081412  0.184495  0.095043  0.040564  0.884390  0.475881  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5202  0.148208  0.030643  0.919165  0.255170  0.853721  0.980877  0.030656
# 5203  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5204  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5205  0.064134  0.104007  0.459270  0.759456  0.951104  0.368111  0.078765
# 5206  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5202  9788172235222
# 5203  9788173031014
# 5204  9788179921623
# 5205  9788185300535
# 5206  9789027712059
#
# [5207 rows x 8 columns]

# %%
books = pd.merge(books, emotion_df, on='isbn13')

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002005883  0002005883
# 2     9780002261982  0002261987
# 3     9780002261982  0002261987
# 4     9780006178736  0006178731
# ...             ...         ...
# 5202  9788172235222  8172235224
# 5203  9788173031014  8173031010
# 5204  9788179921623  817992162X
# 5205  9788185300535  8185300534
# 5206  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                                Gilead
# 2                                          Spider's Web
# 3                                          Spider's Web
# 4                                        Rage of angels
# ...                                                 ...
# 5202                                  Mistaken Identity
# 5203                                Journey to the East
# 5204  The Monk Who Sold His Ferrari: A Fable About F...
# 5205                                          I Am that
# 5206                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                               Marilynne Robinson
# 2                  Charles Osborne;Agatha Christie
# 3                  Charles Osborne;Agatha Christie
# 4                                   Sidney Sheldon
# ...                                            ...
# 5202                              Nayantara Sahgal
# 5203                                 Hermann Hesse
# 5204                                  Robin Sharma
# 5205  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5206                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1                           Fiction
# 2     Detective and mystery stories
# 3     Detective and mystery stories
# 4                           Fiction
# ...                             ...
# 5202        Indic fiction (English)
# 5203              Adventure stories
# 5204               Health & Fitness
# 5205                     Philosophy
# 5206                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=KQZCP...
# 2     http://books.google.com/books/content?id=gA5GP...
# 3     http://books.google.com/books/content?id=gA5GP...
# 4     http://books.google.com/books/content?id=FKo2T...
# ...                                                 ...
# 5202  http://books.google.com/books/content?id=q-tKP...
# 5203  http://books.google.com/books/content?id=rq6JP...
# 5204  http://books.google.com/books/content?id=c_7mf...
# 5205  http://books.google.com/books/content?id=Fv_JP...
# 5206  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A NOVEL THAT READERS and critics have been eag...          2004.0
# 2     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 3     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 4     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# ...                                                 ...             ...
# 5202  On A Train Journey Home To North India After L...          2003.0
# 5203  This book tells the tale of a man who goes on ...          2002.0
# 5204  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5205  This collection of the timeless teachings of o...          1999.0
# 5206  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.85      247.0  ...
# 2               3.83      241.0  ...
# 3               3.83      241.0  ...
# 4               3.93      512.0  ...
# ...              ...        ...  ...
# 5202            2.93      324.0  ...
# 5203            3.70      175.0  ...
# 5204            3.82      198.0  ...
# 5205            4.51      531.0  ...
# 5206            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                                Gilead
# 2                                  Spider's Web:A Novel
# 3                                  Spider's Web:A Novel
# 4                                        Rage of angels
# ...                                                 ...
# 5202                                  Mistaken Identity
# 5203                                Journey to the East
# 5204  The Monk Who Sold His Ferrari: A Fable About F...
# 5205      I Am that:Talks with Sri Nisargadatta Maharaj
# 5206                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 2     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 3     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 4     9780006178736 A memorable, mesmerizing heroine...           Fiction
# ...                                                 ...               ...
# 5202  9788172235222 On A Train Journey Home To North...           Fiction
# 5203  9788173031014 This book tells the tale of a ma...        Nonfiction
# 5204  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5205  9788185300535 This collection of the timeless ...        Nonfiction
# 5206  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   neutral   sadness  surprise
# 0     0.064134  0.273591  0.928168  0.932798  0.646216  0.967157  0.729603
# 1     0.064134  0.273591  0.928168  0.932798  0.646216  0.967157  0.729603
# 2     0.612619  0.348285  0.942528  0.704421  0.887939  0.111690  0.252545
# 3     0.612619  0.348285  0.942528  0.704421  0.887939  0.111690  0.252545
# 4     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5202  0.148208  0.030643  0.919165  0.255170  0.853721  0.980877  0.030656
# 5203  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5204  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5205  0.064134  0.104007  0.459270  0.759456  0.951104  0.368111  0.078765
# 5206  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
# [5207 rows x 21 columns]

# %%
books.to_csv('books_with_emotions.csv', index=False)
